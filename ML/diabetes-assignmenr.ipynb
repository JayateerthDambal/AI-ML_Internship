# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('N:/PycharmProjects/AI-ML_Internship/assets/diabetes.csv')
df.head()
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
df.describe()
# Out:
#           PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# count  1.000000e+04  10000.00000   10000.000000            10000.000000
# mean   1.502122e+06      3.25580     107.850200               71.207500
# std    2.892868e+05      3.40572      31.920909               16.801478
# min    1.000038e+06      0.00000      44.000000               24.000000
# 25%    1.251672e+06      0.00000      84.000000               58.000000
# 50%    1.504394e+06      2.00000     105.000000               72.000000
# 75%    1.754608e+06      6.00000     129.000000               85.000000
# max    1.999997e+06     14.00000     192.000000              117.000000
#
#        TricepsThickness  SerumInsulin           BMI  DiabetesPedigree  \
# count       10000.00000  10000.000000  10000.000000      10000.000000
# mean           28.81760    139.243600     31.567022          0.400944
# std            14.50648    133.777919      9.804366          0.381463
# ...

# %%
df.columns
# Out:
# Index(['PatientID', 'Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure',
#        'TricepsThickness', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age',
#        'Diabetic'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.groupby('Diabetic').size()
# Out:
# Diabetic
# 0    6656
# 1    3344
# dtype: int64

# %% [markdown]
# ### Hence there are 6656 Non-Diabetic Patients and 3344- Diabetic Patients from 10K Total Patients

# %%
df.groupby('Diabetic').hist(figsize=(10, 10))
# Out:
# Diabetic
# 0    [[AxesSubplot(0.125,0.725918;0.215278x0.154082...
# 1    [[AxesSubplot(0.125,0.725918;0.215278x0.154082...
# dtype: object

# %% [markdown]
# #### Here we Got 2 Graph Set for 1 and 0's

# %%
df.isnull().sum()
# Out:
# PatientID                 0
# Pregnancies               0
# PlasmaGlucose             0
# DiastolicBloodPressure    0
# TricepsThickness          0
# SerumInsulin              0
# BMI                       0
# DiabetesPedigree          0
# Age                       0
# Diabetic                  0
# dtype: int64

# %% [markdown]
# ### There are no Nan/ Null values in the Dataset

# %%
df.plot(kind='scatter', x='SerumInsulin', y='Pregnancies')
plt.show()

# %%
df.columns
# Out:
# Index(['PatientID', 'Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure',
#        'TricepsThickness', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age',
#        'Diabetic'],
#       dtype='object')
